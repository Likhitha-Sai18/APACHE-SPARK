# %% [markdown]
# ---
# ---
#
# <center><h1> Assignment: RDDs</h1></center>
#
# ---
# ---
#
# #### `Creating the Spark Context`
#
# ---

# %%
pip install pyspark
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pyspark
#   Downloading pyspark-3.2.4.tar.gz (281.5 MB)
#      |████████████████████████████████| 281.5 MB 55 kB/s  eta 0:00:0101
# Collecting py4j==0.10.9.5
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 116.6 MB/s eta 0:00:01
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.2.4-py2.py3-none-any.whl size=282040935 sha256=16456c0aef2f66bfec926ba9e810d625e0c971f3a1406051b789747f8bf3509e
#   Stored in directory: /home/ana026737/.cache/pip/wheels/7f/b5/ab/6fbc298426a10c8a27065ed80da7241e60146d770f41c80b4d
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.5 pyspark-3.2.4
# Note: you may need to restart the kernel to use updated packages.

# %%
#create SparkConfig
from pyspark import SparkConf
conf=SparkConf().setAppName("MyAPP").setMaster("Local[*]")

# %%
#Create SparkContex


from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("MyApp") \
    .master("local[*]") \
    .getOrCreate()

sc = spark.sparkContext
print("SparkContext created successfully!")
# Out:
# /home/ana026737/.local/lib/python3.6/site-packages/pyspark/context.py:238: FutureWarning: Python 3.6 support is deprecated in Spark 3.2.
#   FutureWarning
# SparkContext created successfully!

# %%
sc
# Out:
# <SparkContext master=local[*] appName=MyApp>

# %% [markdown]
# #### `Creating Sample Pair RDDs`
#
# ---

# %%
# pair RDD A
pair_rdd_A = sc.parallelize([("A", 1000), 
                             ("B", 3244),
                             ("A", 2939),
                             ("A", 2233),
                             ("A", 3920),
                             ("B", 2233)])
# pair RDD B
pair_rdd_B = sc.parallelize([("A", 0),
                             ("B", 1),
                             ("C", 3),
                             ("D", 1),
                             ("E", 2)])

# %% [markdown]
# #### `Collect Both the Pair RDDs`
#
# ---

# %%
# write your code here to collect pair_rdd_A
pair_rdd_A.groupByKey().collect()
# Out:
# [('A', <pyspark.resultiterable.ResultIterable at 0x7f12313e2eb8>),
#  ('B', <pyspark.resultiterable.ResultIterable at 0x7f12313e24e0>)]

# %%
pair_rdd_A.collect()
# Out:
# [('A', 1000), ('B', 3244), ('A', 2939), ('A', 2233), ('A', 3920), ('B', 2233)]

# %%
# write your code here to collect pair_rdd_B
pair_rdd_A.groupByKey().collect()
# Out:
# [('A', <pyspark.resultiterable.ResultIterable at 0x7f123119e908>),
#  ('B', <pyspark.resultiterable.ResultIterable at 0x7f123119ec50>)]

# %%
pair_rdd_B.collect()
# Out:
# [('A', 0), ('B', 1), ('C', 3), ('D', 1), ('E', 2)]

# %% [markdown]
# #### `Use CountByKey to find out the number of data points both in A & B`
#
# ---

# %%
pair_rdd_A.countByKey()
# Out:
# defaultdict(int, {'A': 4, 'B': 2})

# %%
# write your code here
pair_rdd_B.countByKey()
# Out:
# defaultdict(int, {'A': 4, 'B': 2})

# %% [markdown]
# #### `Find all the values agains the Key A & B using lookup in the pair_rdd_B`
#
# ---

# %%
# write your code here to find values against the key A
V_A=pair_rdd_A.lookup("A")
print(V_A)
# Out:
# [1000, 2939, 2233, 3920]

# %%
# write your code here to find values against the key B
V_B=pair_rdd_B.lookup("B")
print(V_B)
# Out:
# [1]

# %% [markdown]
# #### `Use ReduceByKey to find the total sum of values of A & B in the pair_rdd_B`
#
# ---

# %%
# write your code here to find the sum of values of A & B
pair_rdd_B.reduceByKey(lambda x,y:x+y).collect()
# Out:
# [('A', 0), ('D', 1), ('C', 3), ('B', 1), ('E', 2)]

# %% [markdown]
# #### `Join the pair_rdd_A and pair_rdd_B`
#
# ---

# %%
# write your code here
join_rdd=pair_rdd_A.join(pair_rdd_B)
join_rdd.collect()
# Out:
# [('B', (3244, 1)),
#  ('B', (2233, 1)),
#  ('A', (1000, 0)),
#  ('A', (2939, 0)),
#  ('A', (2233, 0)),
#  ('A', (3920, 0))]
